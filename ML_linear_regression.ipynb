# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-202ae450-6f7f-4935-bb34-4119d69697ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-202ae450-6f7f-4935-bb34-4119d69697ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hp.csv to hp.csv
# {'hp.csv': b'area,price\r\n2600,55000\r\n3000,56500\r\n3200,61000\r\n3600,68000\r\n4000,72000\r\n5000,71000\r\n2500,4000\r\n2700,38000\r\n1200,17000\r\n5000,100000\r\n'}

# %%
df = pd.read_csv('hp.csv')
df
# Out:
#    area   price
# 0  2600   55000
# 1  3000   56500
# 2  3200   61000
# 3  3600   68000
# 4  4000   72000
# 5  5000   71000
# 6  2500    4000
# 7  2700   38000
# 8  1200   17000
# 9  5000  100000

# %%
x = df[['area']]
y = df['price']

# %% [markdown]
# *Visualization*
#
# **Visualization**
#
# ~~Visualization~~
#
# # Visualization

# %%
plt.scatter(df['area'], df['price'], marker='+', color='red')
plt.xlabel("Area in sq ft.")
plt.ylabel("Price in taka")
plt.title("Home prices in Dhaka")
# Out:
# Text(0.5, 1.0, 'HOme prices in Dhaka')

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.30, random_state=1)

# %%
xtest
# Out:
#    area
# 2  3200
# 9  5000
# 6  2500

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
reg.predict(xtest)
# Out:
# array([54577.95521897, 81852.07441554, 43971.35330919])

# %%
ytest
# Out:
# 2     61000
# 9    100000
# 6      4000
# Name: price, dtype: int64

# %%
plt.plot(df.area, reg.predict(df[['area']]))

# %%
plt.scatter(df['area'], df['price'], marker='+', color='red')
plt.xlabel("Area in sq ft.")
plt.ylabel("Price in taka")
plt.title("Home prices in Dhaka")
plt.plot(df.area, reg.predict(df[['area']]))

# %%
reg.predict([[1500]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:446: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([28819.06486664])

# %%
#y = mx + c
reg.coef_
# Out:
# array([15.15228844])

# %%
reg.intercept_
# Out:
# 6090.632202831752

# %%
y = 15.15228844 * 1500 + 6090.632202831752
y
# Out:
# 28819.06486283175
